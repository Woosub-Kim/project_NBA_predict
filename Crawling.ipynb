# %% [markdown]
# # crawling
# ##### 데이터는 2002년 부터

# %%
import os
print (os.getcwd()) #현재 디렉토리의 위치확인
# Out:
# C:\04Python\NBA

# %%
# !pip install html5lib
# Out:
# Collecting html5lib
#   Downloading html5lib-1.0.1-py2.py3-none-any.whl (117 kB)
# Requirement already satisfied: six>=1.9 in c:\users\103-04\anaconda3\lib\site-packages (from html5lib) (1.14.0)
# Requirement already satisfied: webencodings in c:\users\103-04\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.0.1
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %% [markdown]
# # 스코어 크롤링

# %%
url = 'https://www.espn.com/nba/schedule/_/date/'+'20190605'
SCORE = pd.read_html(url)[0]#.drop('Unnamed: 5', axis=1)
SCORE
# Out:
#                                     matchup  \
# 0                               Toronto TOR
# 1  NBA FINALS - GAME 3, TOR Lead series 2-1
#
#                                  Unnamed: 1  \
# 0                           Golden State GS
# 1  NBA FINALS - GAME 3, TOR Lead series 2-1
#
#                                      result  \
# 0                           TOR 123, GS 109
# 1  NBA FINALS - GAME 3, TOR Lead series 2-1
#
#                                 winner high  \
# 0                      Kawhi Leonard 30 Pts
# 1  NBA FINALS - GAME 3, TOR Lead series 2-1
#
#                                  loser high  \
# 0                      Stephen Curry 47 Pts
# 1  NBA FINALS - GAME 3, TOR Lead series 2-1
#
#                                  Unnamed: 5
# 0                                       NaN
# 1  NBA FINALS - GAME 3, TOR Lead series 2-1

# %%
import lxml
import pandas as pd
year = [str(i) for i in range(2002,2021)]
month = [str(i) if i>= 10 else '0'+str(i) for i in range(1,13)]

day = [str(i) if i>= 10 else '0'+str(i) for i in range(1,32)]
score_list = []
for y in year:
    print(y)
    for m in month:
        for d in day:
            date = y+m+d
            url = 'https://www.espn.com/nba/schedule/_/date/'+date
            try:
                SCORE = pd.read_html(url)[0].drop('Unnamed: 5', axis=1)
                SCORE.columns = ['matchup','home','result','winner high','loser high']
                SCORE['DATE'] = date
                score_list.append(SCORE)
            except:
                continue

SCORES = pd.concat(score_list)
SCORES.to_csv('NBA_scores.csv')
# Out:
# 2002

# %% [markdown]
# # PER크롤링

# %%
#뒷년도 기준(19-20시즌의 경우 2020)
import lxml
import pandas as pd
year = year = [str(i) for i in range(2002,2021)]
page = [str(i) for i in range(1,11)]
for y in year:
    print(y)
    yearlyPER = []
    for p in page:
        try:
            url = 'http://insider.espn.com/nba/hollinger/statistics/_/page/{}/year/{}'.format(p,y)
            PER = pd.read_html(url, header=1)[0]
            yearlyPER.append(PER)
        except:
            continue
    YPER = pd.concat(yearlyPER)
    YPER.to_csv('./PER/{}_PER.csv'.format(y))
# Out:
#      RK                    PLAYER  GP   MPG   TS%   AST    TO   USG   ORR  \
# 0    51           Jeremy Lin, BKN  36  24.5  .566  25.1  11.7  26.3   1.3
# 1    52          Jeff Teague, IND  82  32.4  .574  32.8  11.1  23.0   1.4
# 2    53     Montrezl Harrell, HOU  58  18.3  .662  12.6   8.7  16.8   8.3
# 3    54       Nikola Vucevic, ORL  75  28.8  .498  14.6   8.2  23.7   8.6
# 4    55        Jabari Parker, MIL  51  33.9  .563  12.4   8.1  24.8   5.4
# 5    56     Willy Hernangomez, NY  72  18.4  .564  13.4  14.0  19.7  13.8
# 6    57         Al Jefferson, IND  66  14.1  .526   9.5   5.5  24.2   9.2
# 7    58                Nene , HOU  67  17.9  .630  10.5  11.7  18.6   8.6
# 8    59     LaMarcus Aldridge, SA  72  32.4  .532   9.9   7.0  23.0   8.5
# 9    60       Richaun Holmes, PHI  57  20.9  .611  10.2   9.6  17.4   8.7
# 50  NaN        Draymond Green, GS  76  32.5  .522  36.5  12.6  17.3   4.7
# 51   98      Serge Ibaka, ORL/TOR  79  30.7  .566   6.2   8.6  19.3   5.8
# 52   99  Willie Cauley-Stein, SAC  75  18.9  .558  11.5   9.9  18.4   7.0
# 53  100      Harrison Barnes, DAL  79  35.5  .541   7.2   6.3  23.1   3.7
#
#      DRR  REBR    PER     VA   EWA
# 0   14.7   8.1  19.33  109.8   3.7
# 1   12.4   7.0  19.24  326.6  10.9
# 2   14.2  11.2  19.23  122.8   4.1
# 3   31.3  19.6  19.19  277.3   9.2
# 4   15.7  10.6  19.15  197.2   6.6
# 5   27.1  20.4  19.00  166.0   5.5
# 6   24.2  16.8  18.96  116.2   3.9
# 7   17.0  12.8  18.91  148.7   5.0
# 8   16.6  12.7  18.66  249.4   8.3
# 9   20.1  14.4  18.61  126.6   4.2
# 10   DRR  REBR    PER     VA   EWA
# 11  27.4  19.2  18.58  188.6   6.3
# 12  12.6   8.1  18.55  215.2   7.2
# 13  19.6  13.0  18.51  300.1  10.0
# 14  21.9  16.9  18.48  154.0   5.1
# 15  22.4  15.6  18.18  242.9   8.1
# 16  16.0   9.3  17.96  282.6   9.4
# 17  17.5  10.8  17.95  112.7   3.8
# 18  19.5  12.5  17.91  224.1   7.5
# 19  18.9  12.0  17.91  103.4   3.4
# 20  18.6  11.8  17.77  234.7   7.8
# 21   DRR  REBR    PER     VA   EWA
# 22  19.5  13.3  17.66  122.5   4.1
# 23  24.1  16.2  17.62  134.7   4.5
# 24  24.8  18.6  17.57  144.7   4.8
# 25   9.2   5.9  17.53  278.0   9.3
# 26  18.2  11.8  17.49  193.3   6.4
# 27  14.7   8.4  17.41  220.2   7.3
# 28  28.1  21.8  17.38   49.1   1.6
# 29  17.1  11.1  17.35  266.3   8.9
# 30  11.9   6.3  17.26   72.0   2.4
# 31  13.9   8.7  17.25  225.1   7.5
# 32   DRR  REBR    PER     VA   EWA
# 33  10.6   6.4  17.19  202.4   6.7
# 34  22.0  17.8  17.14   86.9   2.9
# 35  28.3  14.4  17.10  118.9   4.0
# 36  22.7  12.7  17.09  112.3   3.7
# 37   9.3   6.4  17.05  188.0   6.3
# 38  16.6  10.0  17.03  171.9   5.7
# 39  21.9  14.3  17.02   58.4   1.9
# 40  15.6   8.8  16.95  247.0   8.2
# 41  20.7  15.3  16.91   49.4   1.6
# 42  11.4   7.2  16.87  216.1   7.2
# 43   DRR  REBR    PER     VA   EWA
# 44  17.3  12.9  16.70  157.1   5.2
# 45  33.2  22.6  16.63  116.7   3.9
# 46   8.8   6.3  16.62  278.2   9.3
# 47  18.8  13.0  16.57   64.7   2.2
# 48   8.0   5.5  16.52  160.1   5.3
# 49  15.4  14.2  16.51  210.7   7.0
# 50  20.9  13.3  16.51  184.7   6.2
# 51  19.0  12.2  16.46  179.4   6.0
# 52  20.4  13.7  16.37  122.4   4.1
# 53  13.1   8.2  16.34  244.3   8.1

# %% [markdown]
# # WS 크롤링

# %%
#뒷년도 기준(19-20시즌의 경우 2020)
import lxml
import pandas as pd
year = [str(i) for i in range(2002,2021)]
for y in year:
    print(y)
    url = 'https://www.basketball-reference.com/leagues/NBA_{}_advanced.html#advanced_stats::ws'.format(y)
    WS = pd.read_html(url)[0]
    WS.to_csv('./WS/{}_WS.csv'.format(y))
# Out:
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
