# %% [markdown]
# # crawling

# %%
import os
print (os.getcwd()) #현재 디렉토리의 위치확인
# Out:
# C:\04Python\NBA

# %%
# !pip install html5lib
# Out:
# ...
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %% [markdown]
# # 스코어 크롤링

# %%
#2001제이터도 존재함
import lxml
import pandas as pd
url = 'https://www.espn.com/nba/schedule/_/date/20190401'
teamstat = pd.read_html(url)
for i in teamstat:
    print(i)
# Out:
#             matchup     Unnamed: 1             result  \
# 0       Detroit DET    Indiana IND   IND 111, DET 102
# 1         Miami MIA     Boston BOS   BOS 110, MIA 105
# 2     Milwaukee MIL   Brooklyn BKN   MIL 131, BKN 121
# 3       Chicago CHI    New York NY    NY 113, CHI 105
# 4       Orlando ORL    Toronto TOR   TOR 121, ORL 109
# 5      Portland POR  Minnesota MIN   POR 132, MIN 122
# 6  Philadelphia PHI     Dallas DAL   DAL 122, PHI 102
# 7     Charlotte CHA      Utah UTAH  UTAH 111, CHA 102
# 8     Cleveland CLE    Phoenix PHX   PHX 122, CLE 113
#
#                winner high               loser high  Unnamed: 5
# 0    Thaddeus Young 19 Pts   Wayne Ellington 26 Pts         NaN
# 1      Kyrie Irving 25 Pts      Goran Dragic 30 Pts         NaN
# 2      Eric Bledsoe 29 Pts  D'Angelo Russell 28 Pts         NaN
# 3       Luke Kornet 24 Pts       Robin Lopez 29 Pts         NaN
# 4       Danny Green 29 Pts     Evan Fournier 21 Pts         NaN
# ...

# %% [markdown]
# # PER크롤링

# %%
#02-03시즌부터, 년단위
import lxml
import pandas as pd
url = 'http://insider.espn.com/nba/hollinger/statistics/_/year/2020'
PER = pd.read_html(url, header=1)[0]
PER
# Out:
#      RK                      PLAYER  GP   MPG   TS%   AST    TO   USG   ORR  \
# 0     1  Giannis Antetokounmpo, MIL  57  30.9  .608  17.1  10.8  37.1   7.8
# 1     2          Anthony Davis, LAL  54  34.3  .614  11.5   9.1  29.2   7.3
# 2     3           James Harden, HOU  60  36.8  .614  18.5  11.3  36.8   3.0
# 3     4            Luka Doncic, DAL  52  33.1  .583  23.3  11.3  38.6   4.1
# 4     5          Kawhi Leonard, LAC  50  32.4  .583  16.1   9.1  33.5   3.4
# 5     6     Karl-Anthony Towns, MIN  35  33.9  .642  15.5  11.2  28.8   8.1
# 6     7           Kyrie Irving, BKN  20  32.9  .595  20.0   8.1  33.4   3.5
# 7     8         Damian Lillard, POR  57  36.8  .618  22.9   8.5  31.2   1.5
# 8     9           LeBron James, LAL  59  34.9  .581  29.0  10.9  33.7   3.1
# 9    10            Joel Embiid, PHI  43  30.3  .591  12.1  11.8  31.9   9.9
# 10   RK                      PLAYER  GP   MPG   TS%   AST    TO   USG   ORR
# ...
